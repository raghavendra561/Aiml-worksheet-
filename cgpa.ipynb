# %%
age=int(input("enter age"))
if age <=6 :
  print("no ticket")
elif age >6 and age<=12:
    print ("half ticket")
else:
      print ("full ticket")
# Out:
# enter age8
# half ticket

# %%
CGPA=int(input("enter CGPA"))
backlog= int(input("enter backlog"))
sem=int(input("enter sem"))
if CGPA>=8 and backlog==0 and sem==8:
    print("student is eligible for placement")
else:
    print("student is not eligible for placement")
# Out:
# enter CGPA8
# enter backlog0
# enter sem8
# student is eligible for placement

# %%
Plc=int(input("enter CGPA"))
backlog= int(input("enter backlog"))
sem=int(input("enter sem"))
if  CGPA>=8 and backlog==0 and sem==8:
    print("student is eligible for placement")
else:
    print("student is not eligible for placement")
# Out:
# enter CGPA8
# enter backlog0
# enter sem8
# student is eligible for placement
