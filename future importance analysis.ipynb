# %%
import pandas as pd
# Farm dataset with many tracked factors
data = {
 "Rainfall_mm": [200, 180, 220, 210, 190, 230],
 "Soil_Moisture": [30, 28, 35, 33, 29, 36],
 "Humidity": [80, 75, 85, 82, 78, 88],
 "Wind_Speed": [10, 12, 9, 11, 10, 8],
 "Yield_kg": [3200, 3000, 3500, 3400, 3100, 3600]
}
df = pd.DataFrame(data)
df
# Out:
#    Rainfall_mm  Soil_Moisture  Humidity  Wind_Speed  Yield_kg
# 0          200             30        80          10      3200
# 1          180             28        75          12      3000
# 2          220             35        85           9      3500
# 3          210             33        82          11      3400
# 4          190             29        78          10      3100
# 5          230             36        88           8      3600

# %%
importances = model.feature_importances_
feature_importance = pd.Series(
 importances,
 index=X.columns
)
feature_importance
# Out:
# Rainfall_mm      0.319859
# Soil_Moisture    0.337573
# Humidity         0.248088
# Wind_Speed       0.094479
# dtype: float64

# %%
feature_importance.sort_values(ascending=False)
# Out:
# Soil_Moisture    0.337573
# Rainfall_mm      0.319859
# Humidity         0.248088
# Wind_Speed       0.094479
# dtype: float64

# %%
feature_importance.sort_values().plot(
    kind="barh",
    title="Feature Importance for Yield Prediction"
)
# Out:
# <Axes: title={'center': 'Feature Importance for Yield Prediction'}>
